# %%
from random import gauss
import numpy as np
import matplotlib.pyplot as plt

# %%
def AR(coef, N, sigma2):
    
    """Computes an AR process with given coefficients and innovation variance sigma**2"""
    """The formula at any rank N is given by XN = N(0,sigma2) (this is Zt) + sum_i=1^N ai X_N-i"""
    """We assume coef starts at a1"""
    
    Lcoef = len(coef)
    X = [gauss(0,sigma2)]
    for i in range(N+1):
        tmp = gauss(0,sigma2)
        for k in range(0,min(i,Lcoef)):
            tmp += coef[k]*X[i-1-k]
        X.append(tmp)
    return X #We will return the whole AR process and not just the XN value, as it may be useful. Also, to get specifically XN, we can just call X[-1], it's quick enough.

# %%
N=500
AR1 = AR([-0.7],N,1)
absc = np.linspace(0,N,N+2)
plt.plot(absc, AR1, label='AR1 process with a1 = -0.7')
plt.legend()
plt.show()

# %%
def periodogram(X, method='sta', window = 'rec'):

    N, Sxx = len(X), 0
    if(method == 'sta'):
        Sxx = abs(np.fft.fft(X,2*N-1))**2/N
        return Sxx
    
    if(method == 'bar'):
        M=2**(np.floor(np.log(N)/np.log(2)-1))
        L=np.floor(2*N/M)-1
        M,L = int(M), int(L)
        for i in range(M*L-len(X)): #Zero-padding to match closest upwards power of two
            X.append(0)
        for i in range(L):
            Sxx += abs(np.fft.fft(X[i*M:(i+1)*M]))**2/(M*L)
        return Sxx
    
    if(method == 'wel'):
        M=int(2**(np.floor(np.log(N)/np.log(2)-1)))
        S=int(2*np.ceil(N/M))
        if window == 'rec':
            w = [1]*M
            #To Do (if we need to use windows later for Welch method)
        for i in range(M*S-len(X)): #Zero-padding to match closest upwards power of two
            X.append(0)
        K=M//2
        for i in range(S):
            P=0
            for k in range(M):
                P+=w[k]**2/N
            Sxx += abs(np.fft.fft(np.multiply(w,X[i*K:i*K+M])))**2/(M*P*S)
            print(len(Sxx))
        return Sxx
    
    #There used to be a problem, it was the zero padding. I added until it matched N, but not len(X), which added 0 each time it was called, even unnecessary ones.

# %%
def PSD_ar1(a1,sigma2,nu):
    return abs(1-a1*np.exp(-2j*np.pi*nu))**2

# %%
period_stand = periodogram(AR1)
absc = np.linspace(-0.5,0.5,len(period_stand))
absc2 = np.linspace(0,0.5,len(period_stand)//2)
ordo2 = PSD_ar1(-0.7, 1, absc2)
absc2 = np.flip(absc2)
ordo1 = np.concatenate(PSD_ar1(-0.7, 1, absc2),ordo2)
plt.plot(absc, period_stand, label = 'standard method for AR1 periodogram')
plt.plot(absc, ordo1, label = 'known PSD for AR1 periodogram')
plt.legend()
plt.show()

# %%
plt.close()
period_bart = periodogram(AR1,'bar')
plt.plot(np.linspace(-0.5,0.5,len(period_bart)), period_bart)
plt.show()

# %%
plt.close()
period_welc = periodogram(AR1,'wel')
plt.plot(np.linspace(-0.5,0.5,len(period_bart)), period_welc)
plt.show()
# Out:
# 1024
# 1
# 1024
# 1
# 1024
# 1
# 1024
# 1
# 1024
# 1
# 1024
# 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\GUILLA~1\AppData\Local\Temp/ipykernel_17768/776401719.py in <module>
#       1 plt.close()
#       2 period_welc = periodogram(AR1,'wel')
# ----> 3 plt.plot(np.linspace(-0.5,0.5,len(period_bart)), period_welc)
#       4 plt.show()
#
# ~\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# ~\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# --> 315             yield from self._plot_args(this, kwargs)
#     316
#     317     def get_next_color(self):
#
# ~\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     499
#     500         if x.shape[0] != y.shape[0]:
# --> 501             raise ValueError(f"x and y must have same first dimension, but "
#     502                              f"have shapes {x.shape} and {y.shape}")
#     503         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (512,) and (1024,)

# %%
A=[0,1,2,3,4,5,6]
np.multiply(A[2:4],A[1:3])
# Out:
# array([2, 6])
